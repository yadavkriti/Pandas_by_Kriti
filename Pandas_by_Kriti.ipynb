# %% [markdown]
# # Easy Notes on Pandas function in Python

# %% [markdown]
# ### Importing pandas library

# %%
import pandas as pd

# %% [markdown]
# ### Going to use pandas function on the dataset called "MobilePrice". This is csv dataset (comma separated values) <br> Load a CSV file into a Pandas DataFrame: <br> This Pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns)

# %%
mobileprice= pd.read_csv("MobilePrice.csv")

# %%
mobileprice
# Out:
#       battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels  \
# 0               842        No          2.2       No                     1
# 1              1021       Yes          0.5      Yes                     0
# 2               563       Yes          0.5      Yes                     2
# 3               615       Yes          2.5       No                     0
# 4              1821       Yes          1.2       No                    13
# ...             ...       ...          ...      ...                   ...
# 1995            794       Yes          0.5      Yes                     0
# 1996           1965       Yes          2.6      Yes                     0
# 1997           1911        No          0.9      Yes                     1
# 1998           1512        No          0.9       No                     4
# 1999            510       Yes          2.0      Yes                     5
#
#      has_4g  int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width  \
# ...

# %% [markdown]
# ### The head(n) method returns n number of rows, string from the top. <br>The head() method returns the first 5 rows if a number is not specified.

# %%
df=pd.DataFrame(mobileprice)
df.head()
# Out:
#    battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels has_4g  \
# 0            842        No          2.2       No                     1     No
# 1           1021       Yes          0.5      Yes                     0    Yes
# 2            563       Yes          0.5      Yes                     2    Yes
# 3            615       Yes          2.5       No                     0     No
# 4           1821       Yes          1.2       No                    13    Yes
#
#    int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  \
# 0           7    0.6        188        2  ...         20       756  2549
# 1          53    0.7        136        3  ...        905      1988  2631
# 2          41    0.9        145        5  ...       1263      1716  2603
# 3          10    0.8        131        6  ...       1216      1786  2769
# 4          44    0.6        141        2  ...       1208      1212  1411
#
# ...

# %% [markdown]
# ### The tail(n) method returns n number of last rows. <br> The tail() method returns the last 5 rows if a number is not specified.

# %%
df.tail()
# Out:
#       battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels  \
# 1995            794       Yes          0.5      Yes                     0
# 1996           1965       Yes          2.6      Yes                     0
# 1997           1911        No          0.9      Yes                     1
# 1998           1512        No          0.9       No                     4
# 1999            510       Yes          2.0      Yes                     5
#
#      has_4g  int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width  \
# 1995    Yes           2    0.8        106        6  ...       1222      1890
# 1996     No          39    0.2        187        4  ...        915      1965
# 1997    Yes          36    0.7        108        8  ...        868      1632
# 1998    Yes          46    0.1        145        5  ...        336       670
# 1999    Yes          45    0.9        168        6  ...        483       754
#
# ...

# %% [markdown]
# ### .loc attribute to access a particular cell in the given Dataframe using the index and column labels.

# %%
print(df.loc[[0,1]])
# Out:
#    battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels has_4g  \
# 0            842        No          2.2       No                     1     No
# 1           1021       Yes          0.5      Yes                     0    Yes
#
#    int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  \
# 0           7    0.6        188        2  ...         20       756  2549
# 1          53    0.7        136        3  ...        905      1988  2631
#
#    sc_h  sc_w  talk_time  has_3g touch_screen wifi  price_range
# 0     9     7         19      No           No  Yes  Medium Cost
# 1    17     3          7     Yes          Yes   No    High Cost
#
# [2 rows x 21 columns]

# %% [markdown]
# ### df.columns will provide list of the name of columns of the dataframe

# %%
df.columns
# Out:
# Index(['battery_power', 'bluetooth', 'clock_speed', 'dual_sim',
#        'front_camera_mpixels', 'has_4g', 'int_memory', 'm_dep', 'mobile_wt',
#        'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w',
#        'talk_time', 'has_3g', 'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
columns_list=df.columns.to_list()
columns_list
# Out:
# ['battery_power',
#  'bluetooth',
#  'clock_speed',
#  'dual_sim',
#  'front_camera_mpixels',
#  'has_4g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'has_3g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %% [markdown]
# ### df.loc[0] will access the details of the first row of the dataframe

# %%
print(df.loc[0])
# Out:
# battery_power                   842
# bluetooth                        No
# clock_speed                     2.2
# dual_sim                         No
# front_camera_mpixels              1
# has_4g                           No
# int_memory                        7
# m_dep                           0.6
# mobile_wt                       188
# n_cores                           2
# pc                                2
# px_height                        20
# px_width                        756
# ram                            2549
# sc_h                              9
# sc_w                              7
# talk_time                        19
# has_3g                           No
# touch_screen                     No
# wifi                            Yes
# price_range             Medium Cost
# Name: 0, dtype: object

# %% [markdown]
# ### df.info() prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   battery_power         2000 non-null   int64
#  1   bluetooth             2000 non-null   object
#  2   clock_speed           2000 non-null   float64
#  3   dual_sim              2000 non-null   object
#  4   front_camera_mpixels  2000 non-null   int64
#  5   has_4g                2000 non-null   object
#  6   int_memory            2000 non-null   int64
#  7   m_dep                 2000 non-null   float64
#  8   mobile_wt             2000 non-null   int64
#  9   n_cores               2000 non-null   int64
#  10  pc                    2000 non-null   int64
#  11  px_height             2000 non-null   int64
#  12  px_width              2000 non-null   int64
#  13  ram                   2000 non-null   int64
#  14  sc_h                  2000 non-null   int64
# ...

# %% [markdown]
# ### df.describe() gives the descriptive statistics such as count, mean, std, minimum, percentiles.

# %%
df.describe()
# Out:
#        battery_power  clock_speed  front_camera_mpixels   int_memory  \
# count    2000.000000  2000.000000           2000.000000  2000.000000
# mean     1238.518500     1.522250              4.309500    32.046500
# std       439.418206     0.816004              4.341444    18.145715
# min       501.000000     0.500000              0.000000     2.000000
# 25%       851.750000     0.700000              1.000000    16.000000
# 50%      1226.000000     1.500000              3.000000    32.000000
# 75%      1615.250000     2.200000              7.000000    48.000000
# max      1998.000000     3.000000             19.000000    64.000000
#
#              m_dep    mobile_wt      n_cores           pc    px_height  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.501750   140.249000     4.520500     9.916500   645.108000
# std       0.288416    35.399655     2.287837     6.064315   443.780811
# ...

# %% [markdown]
# ### df[0:3] gives the three row of the dataframe

# %%
df[0:3]
# Out:
#    battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels has_4g  \
# 0            842        No          2.2       No                     1     No
# 1           1021       Yes          0.5      Yes                     0    Yes
# 2            563       Yes          0.5      Yes                     2    Yes
#
#    int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  \
# 0           7    0.6        188        2  ...         20       756  2549
# 1          53    0.7        136        3  ...        905      1988  2631
# 2          41    0.9        145        5  ...       1263      1716  2603
#
#    sc_h  sc_w  talk_time  has_3g touch_screen wifi  price_range
# 0     9     7         19      No           No  Yes  Medium Cost
# 1    17     3          7     Yes          Yes   No    High Cost
# 2    11     2          9     Yes          Yes   No    High Cost
#
# [3 rows x 21 columns]

# %% [markdown]
# ### The iloc() function in python is one of the functions defined in the Pandas module that helps us to select a specific row or column from the data set.

# %%
df.iloc[6]
# Out:
# battery_power                     1821
# bluetooth                           No
# clock_speed                        1.7
# dual_sim                            No
# front_camera_mpixels                 4
# has_4g                             Yes
# int_memory                          10
# m_dep                              0.8
# mobile_wt                          139
# n_cores                              8
# pc                                  10
# px_height                          381
# px_width                          1018
# ram                               3220
# sc_h                                13
# sc_w                                 8
# talk_time                           18
# has_3g                             Yes
# touch_screen                        No
# wifi                               Yes
# price_range             Very High Cost
# Name: 6, dtype: object

# %% [markdown]
# ### df.iloc[2,2] gives the intersection of the second row and second column of the dataframe

# %%
df.iloc[2,2]
# Out:
# 0.5

# %% [markdown]
# ### df.drop will drop the specific columns or rows from dataframe.

# %%
df=df.drop(columns=["mobile_wt","px_height","px_width","touch_screen","sc_h","sc_w"])
df
# Out:
#       battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels  \
# 0               842        No          2.2       No                     1
# 1              1021       Yes          0.5      Yes                     0
# 2               563       Yes          0.5      Yes                     2
# 3               615       Yes          2.5       No                     0
# 4              1821       Yes          1.2       No                    13
# ...             ...       ...          ...      ...                   ...
# 1995            794       Yes          0.5      Yes                     0
# 1996           1965       Yes          2.6      Yes                     0
# 1997           1911        No          0.9      Yes                     1
# 1998           1512        No          0.9       No                     4
# 1999            510       Yes          2.0      Yes                     5
#
#      has_4g  int_memory  m_dep  n_cores  pc   ram  talk_time has_3g wifi  \
# ...

# %%
df.loc[[1,78,89,100],['bluetooth','ram','wifi','price_range']]
# Out:
#     bluetooth   ram wifi     price_range
# 1         Yes  2631   No       High Cost
# 78        Yes  3448  Yes  Very High Cost
# 89         No  2334  Yes       High Cost
# 100       Yes  2600   No  Very High Cost

# %% [markdown]
# ### Pandas sample() is used to generate a sample random row or column from dataframe.

# %%
df_sample=df.sample(n=10)
df_sample
# Out:
#       battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels  \
# 1607            744        No          1.7      Yes                     0
# 1253            712        No          2.5      Yes                     1
# 1483            565        No          0.6      Yes                     1
# 120            1701       Yes          1.6      Yes                     3
# 192            1490       Yes          0.5      Yes                     4
# 1924           1982       Yes          1.6       No                     2
# 1127            618        No          0.6       No                     8
# 1860           1646        No          2.5       No                     3
# 678            1793        No          1.8      Yes                    10
# 601            1595       Yes          0.8      Yes                     0
#
#      has_4g  int_memory  m_dep  n_cores  pc   ram  talk_time has_3g wifi  \
# 1607    Yes          33    0.5        4   2  2700         19    Yes   No
# ...

# %% [markdown]
# ### Pandas sample(frac=n) is used to generate n percent random row of the dataframe

# %%
df_sample2=df.sample(frac=0.05)
df_sample2
# Out:
#       battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels  \
# 54             1073       Yes          0.5      Yes                     0
# 1868           1766       Yes          0.5      Yes                     1
# 621            1944       Yes          0.5       No                     5
# 1666           1715       Yes          0.5      Yes                     1
# 1847           1685        No          0.6       No                    14
# ...             ...       ...          ...      ...                   ...
# 1661           1902        No          0.5       No                    10
# 1422           1109        No          2.1       No                     1
# 1444           1237       Yes          2.5       No                     7
# 374            1334       Yes          2.4       No                     5
# 1677            614       Yes          0.7       No                     4
#
#      has_4g  int_memory  m_dep  n_cores  pc   ram  talk_time has_3g wifi  \
# ...

# %% [markdown]
# ### The nunique() method returns the number of unique values for each column.

# %%
df.nunique()
# Out:
# battery_power           1094
# bluetooth                  2
# clock_speed               26
# dual_sim                   2
# front_camera_mpixels      20
# has_4g                     2
# int_memory                63
# m_dep                     10
# n_cores                    8
# pc                        21
# ram                     1562
# talk_time                 19
# has_3g                     2
# wifi                       2
# price_range                4
# dtype: int64

# %% [markdown]
# ### df.sort_values will sort rows or columns by the specified row or column

# %%
df.sort_values(by='price_range', ascending=False)
# Out:
#       battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels  \
# 1999            510       Yes          2.0      Yes                     5
# 1303            888        No          2.6      Yes                     2
# 479            1589       Yes          2.2      Yes                     2
# 481            1697       Yes          0.7       No                     1
# 483            1476        No          0.5       No                     0
# ...             ...       ...          ...      ...                   ...
# 1562           1325        No          1.9       No                     2
# 307            1751        No          0.5      Yes                     6
# 1117           1970        No          1.6      Yes                    11
# 1115            501       Yes          0.5      Yes                    14
# 1000            594        No          0.8       No                     2
#
#      has_4g  int_memory  m_dep  n_cores  pc   ram  talk_time has_3g wifi  \
# ...

# %% [markdown]
# ### df.T will transpose the dataframe

# %%
df1=df.T

# %%
df2=pd.DataFrame(df1,index=["battery_power","has_4g","touch_screen","price_range"])
df2
# Out:
#                       0          1          2          3            4     \
# battery_power          842       1021        563        615         1821
# has_4g                  No        Yes        Yes         No          Yes
# touch_screen           NaN        NaN        NaN        NaN          NaN
# price_range    Medium Cost  High Cost  High Cost  High Cost  Medium Cost
#
#                       5               6         7         8         9     ...  \
# battery_power         1859            1821      1954      1445       509  ...
# has_4g                  No             Yes        No        No       Yes  ...
# touch_screen           NaN             NaN       NaN       NaN       NaN  ...
# price_range    Medium Cost  Very High Cost  Low Cost  Low Cost  Low Cost  ...
#
#                    1990            1991      1992            1993  \
# battery_power      1617            1882       674            1467
# has_4g              Yes             Yes        No              No
# ...

# %% [markdown]
# ### Creating the dataframe

# %%
df11 = pd.DataFrame({'A':[1,2,np.nan],'B':[5,np.nan,6],'C':[1,2,3]})
df11['States']="CA NV AZ".split()
df11.set_index('States',inplace=True)
print(df11)
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  6.0  3

# %% [markdown]
# ### df.dropna will drop null rows and columns

# %%
print("\nDropping any rows with a NaN value\n",'-'*35, sep='')
print(df11.dropna(axis=0))
# Out:
# Dropping any rows with a NaN value
# -----------------------------------
#           A    B  C
# States
# CA      1.0  5.0  1

# %%
print("\nDropping any column with a NaN value\n",'-'*35, sep='')
print(df11.dropna(axis=1))
# Out:
# Dropping any column with a NaN value
# -----------------------------------
#         C
# States
# CA      1
# NV      2
# AZ      3

# %%
print("\nFilling values with a default value\n",'-'*35, sep='')
print(df.fillna(value='FILL VALUE'))
# Out:
# Filling values with a default value
# -----------------------------------
#       battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels  \
# 0               842        No          2.2       No                     1
# 1              1021       Yes          0.5      Yes                     0
# 2               563       Yes          0.5      Yes                     2
# 3               615       Yes          2.5       No                     0
# 4              1821       Yes          1.2       No                    13
# ...             ...       ...          ...      ...                   ...
# 1995            794       Yes          0.5      Yes                     0
# 1996           1965       Yes          2.6      Yes                     0
# 1997           1911        No          0.9      Yes                     1
# 1998           1512        No          0.9       No                     4
# 1999            510       Yes          2.0      Yes                     5
#
# ...

# %%
# Create dataframe
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}
df = pd.DataFrame(data)
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
byComp = df.groupby('Company')
print("\nGrouping by 'Company' column and listing mean sales\n",'-'*55, sep='')
print(byComp.mean())
# Out:
# Grouping by 'Company' column and listing mean sales
# -------------------------------------------------------
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %% [markdown]
# ### Creating the dataframes and merging along both the axis

# %%
data1={'A':[1,2,3,5,4,8],'B':[1,2,3,4,7,5],'C':[5,6,8,9,42,3]}
D=pd.DataFrame(data1)
D
# Out:
#    A  B   C
# 0  1  1   5
# 1  2  2   6
# 2  3  3   8
# 3  5  4   9
# 4  4  7  42
# 5  8  5   3

# %%
data2={'D':[3,4,5,6,7,8],'E':[4,5,6,7,8,9],'F':[3,4,5,6,78,8]}
D1=pd.DataFrame(data2)
D1
# Out:
#    D  E   F
# 0  3  4   3
# 1  4  5   4
# 2  5  6   5
# 3  6  7   6
# 4  7  8  78
# 5  8  9   8

# %%
df_cat1 = pd.concat([D,D1], axis=1)
df_cat1
# Out:
#    A  B   C  D  E   F
# 0  1  1   5  3  4   3
# 1  2  2   6  4  5   4
# 2  3  3   8  5  6   5
# 3  5  4   9  6  7   6
# 4  4  7  42  7  8  78
# 5  8  5   3  8  9   8

# %%
df_cat1 = pd.concat([D,D1], axis=0)
df_cat1
# Out:
#      A    B     C    D    E     F
# 0  1.0  1.0   5.0  NaN  NaN   NaN
# 1  2.0  2.0   6.0  NaN  NaN   NaN
# 2  3.0  3.0   8.0  NaN  NaN   NaN
# 3  5.0  4.0   9.0  NaN  NaN   NaN
# 4  4.0  7.0  42.0  NaN  NaN   NaN
# 5  8.0  5.0   3.0  NaN  NaN   NaN
# 0  NaN  NaN   NaN  3.0  4.0   3.0
# 1  NaN  NaN   NaN  4.0  5.0   4.0
# 2  NaN  NaN   NaN  5.0  6.0   5.0
# 3  NaN  NaN   NaN  6.0  7.0   6.0
# 4  NaN  NaN   NaN  7.0  8.0  78.0
# 5  NaN  NaN   NaN  8.0  9.0   8.0

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2
